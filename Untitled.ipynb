# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("apple_jobs.csv")
df
# Out:
#                                       title  \
# 0                       Software Technician
# 1                         Software Engineer
# 2                         Software Engineer
# 3                         Software Engineer
# 4                         Software Engineer
# ...                                     ...
# 2143   Enterprise Carrier Account Executive
# 2144             Major Account Lead, Russia
# 2145  Business Solutions Manager, Education
# 2146                Enterprise Channel Lead
# 2147                    Consulting Engineer
#
#                                                location  \
# 0     Santa Clara Valley (Cupertino), California, Un...
# 1     Santa Clara Valley (Cupertino), California, Un...
# 2     Santa Clara Valley (Cupertino), California, Un...
# 3     Santa Clara Valley (Cupertino), California, Un...
# 4     Santa Clara Valley (Cupertino), California, Un...
# ...                                                 ...
# ...

# %%
df.head(30)
# Out:
#                                                 title  \
# 0                                 Software Technician
# 1                                   Software Engineer
# 2                                   Software Engineer
# 3                                   Software Engineer
# 4                                   Software Engineer
# 5                                   Software Engineer
# 6                                   Software Engineer
# 7                                   Software Engineer
# 8                                   Software Engineer
# 9                                   Software Engineer
# 10                                  Software Engineer
# 11                                  Software Engineer
# 12                                  Software Engineer
# 13                                  Software Engineer
# 14                                  Software Engineer
# 15                                 Software Developer
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2148 entries, 0 to 2147
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 2148 non-null   object
#  1   location              2148 non-null   object
#  2   minimum_qual          2148 non-null   object
#  3   preferred_qual        744 non-null    object
#  4   responsibilities      2148 non-null   object
#  5   education&experience  2069 non-null   object
# dtypes: object(6)
# memory usage: 100.8+ KB

# %%
df.isnull().sum()
# Out:
# title                      0
# location                   0
# minimum_qual               0
# preferred_qual          1404
# responsibilities           0
# education&experience      79
# dtype: int64

# %%
df['preferred_qual'].fillna('Not specified', inplace=True)
df['education&experience'].fillna('Not specified', inplace=True)

# %%
df.isnull().sum()
# Out:
# title                   0
# location                0
# minimum_qual            0
# preferred_qual          0
# responsibilities        0
# education&experience    0
# dtype: int64

# %%
df['preferred_qual'] = df['preferred_qual'].fillna('Not specified')
df['education&experience'] = df['education&experience'].fillna('Not specified')

# %%
df.isnull().sum()
# Out:
# title                   0
# location                0
# minimum_qual            0
# preferred_qual          0
# responsibilities        0
# education&experience    0
# dtype: int64

# %%
df.head()
# Out:
#                  title                                           location  \
# 0  Software Technician  Santa Clara Valley (Cupertino), California, Un...
# 1    Software Engineer  Santa Clara Valley (Cupertino), California, Un...
# 2    Software Engineer  Santa Clara Valley (Cupertino), California, Un...
# 3    Software Engineer  Santa Clara Valley (Cupertino), California, Un...
# 4    Software Engineer  Santa Clara Valley (Cupertino), California, Un...
#
#                                         minimum_qual  \
# 0  2-5 years experience supporting or deploying a...
# 1  KEY QUALIFICATIONS\nA genuine passion for fixi...
# 2  - 3+ years experience working on large scale d...
# 3  - 3+ years experience working on large scale d...
# 4  Demonstrated experience integrating full-syste...
#
#                                       preferred_qual  \
# 0                                      Not specified
# 1  ADDITIONAL REQUIREMENTS\nReal hands-on experie...
# ...

# %%
df.head(50)
# Out:
#                                                 title  \
# 0                                 Software Technician
# 1                                   Software Engineer
# 2                                   Software Engineer
# 3                                   Software Engineer
# 4                                   Software Engineer
# 5                                   Software Engineer
# 6                                   Software Engineer
# 7                                   Software Engineer
# 8                                   Software Engineer
# 9                                   Software Engineer
# 10                                  Software Engineer
# 11                                  Software Engineer
# 12                                  Software Engineer
# 13                                  Software Engineer
# 14                                  Software Engineer
# 15                                 Software Developer
# ...

# %%
df.tail(50)
# Out:
#                                                   title  \
# 2098                          SoC Power Model Architect
# 2099            Marketing Operations Manager, App Store
# 2100                           Pop Lifestyle Programmer
# 2101  AppleCare Business & Education Technical Advis...
# 2102          Product Support Readiness Project Manager
# 2103                        Senior Cell Design Engineer
# 2104           Video Original Content IS&T (Production)
# 2105  AppleCare Enterprise Support Advisor (Korean/E...
# 2106  Media Marketing Manager, India: Apple Music, i...
# 2107                  Marcom Group Interactive Director
# 2108                                   Mapping Engineer
# 2109  Apple Music, Global Campaigns & Programs Producer
# 2110        Site Reliability Engineer, Network Security
# 2111        Site Reliability Engineer, Network Security
# 2112                   Senior Technical Project Manager
# 2113               Global Campaigns & Programs Producer
# ...

# %%
df.dropna()
# Out:
#                                       title  \
# 0                       Software Technician
# 1                         Software Engineer
# 2                         Software Engineer
# 3                         Software Engineer
# 4                         Software Engineer
# ...                                     ...
# 2143   Enterprise Carrier Account Executive
# 2144             Major Account Lead, Russia
# 2145  Business Solutions Manager, Education
# 2146                Enterprise Channel Lead
# 2147                    Consulting Engineer
#
#                                                location  \
# 0     Santa Clara Valley (Cupertino), California, Un...
# 1     Santa Clara Valley (Cupertino), California, Un...
# 2     Santa Clara Valley (Cupertino), California, Un...
# 3     Santa Clara Valley (Cupertino), California, Un...
# 4     Santa Clara Valley (Cupertino), California, Un...
# ...                                                 ...
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                     title                                           location  \
# count                2148                                               2148
# unique               1771                                                 77
# top     Software Engineer  Santa Clara Valley (Cupertino), California, Un...
# freq                   16                                               1525
#
#                                              minimum_qual preferred_qual  \
# count                                                2148           2148
# unique                                               1881            577
# top     Strong academic and publication record\nDeep t...  Not specified
# freq                                                    6           1404
#
#                                          responsibilities education&experience
# count                                                2148                 2148
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 2143    False
# 2144    False
# 2145    False
# 2146    False
# 2147    False
# Length: 2148, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(112)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 4       False
# 5       False
#         ...
# 2143    False
# 2144    False
# 2145    False
# 2146    False
# 2147    False
# Length: 2036, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                  title                                           location  \
# 0  Software Technician  Santa Clara Valley (Cupertino), California, Un...
# 1    Software Engineer  Santa Clara Valley (Cupertino), California, Un...
# 2    Software Engineer  Santa Clara Valley (Cupertino), California, Un...
# 4    Software Engineer  Santa Clara Valley (Cupertino), California, Un...
# 5    Software Engineer  Santa Clara Valley (Cupertino), California, Un...
#
#                                         minimum_qual  \
# 0  2-5 years experience supporting or deploying a...
# 1  KEY QUALIFICATIONS\nA genuine passion for fixi...
# 2  - 3+ years experience working on large scale d...
# 4  Demonstrated experience integrating full-syste...
# 5  A successful track-record and proven experienc...
#
#                                       preferred_qual  \
# 0                                      Not specified
# 1  ADDITIONAL REQUIREMENTS\nReal hands-on experie...
# ...

# %%
df.columns.values
# Out:
# array(['title', 'location', 'minimum_qual', 'preferred_qual',
#        'responsibilities', 'education&experience'], dtype=object)
